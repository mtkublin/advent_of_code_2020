# %%
class Ship:
    def __init__(self, fp="input_12.txt"):
        self.navigations = self._load_data(fp)
        
        self.y = 0
        self.x = 0
        
        self.direction = 90
    
    @staticmethod
    def _load_data(fp):
        with open(fp, "r") as f:
            data = [(l[0], int(l[1:])) for l in f.read().split("\n") if l]
        return data
    
    def turn_right(self, degrees):
        self.direction += degrees
        if self.direction >= 360:
            self.direction -= 360
            
    def turn_left(self, degrees):
        self.direction -= degrees
        if self.direction < 0:
            self.direction += 360
            
    def move_forward(self, distance):
        direction_dict = {
            0: self.move_north,
            90: self.move_east,
            180: self.move_south,
            270: self.move_west
        }
        direction_dict[self.direction](distance)
    
    def move_north(self, distance):
        self.y += distance
        
    def move_east(self, distance):
        self.x += distance
        
    def move_south(self, distance):
        self.y -= distance
    
    def move_west(self, distance):
        self.x -= distance
    
    def navigate(self, instruction, value):
        move_dict = {
            "N": self.move_north,
            "S": self.move_south,
            "E": self.move_east,
            "W": self.move_west,
            "L": self.turn_left,
            "R": self.turn_right,
            "F": self.move_forward
        }
        move_dict[instruction](value)
    
    def eval_position(self):
        for instruction in self.navigations:
            self.navigate(*instruction)

    @property 
    def manhattan_distance(self):
        return int(abs(self.x) + abs(self.y))

# %%
# s = Ship("test_input_12.txt")
s = Ship()
s.eval_position()
s.manhattan_distance
# Out:
# 439

# %%
class WayPoint:
    def __init__(self, x, y):        
        self.y = y
        self.x = x
    
    def rotate(self, degrees, x, y, direction):        
        turns = degrees / 90
        if direction == "L":
            turns = -turns
        
        if turns in (-2, 2):
            self.x, self.y = -self.x, -self.y
        elif turns in (-3, 1):
            self.x, self.y = self.y, -self.x
        elif turns in (-1, 3):
            self.x, self.y = -self.y, self.x

    def move_north(self, distance, *args, **kwargs):
        self.y += distance
        
    def move_east(self, distance, *args, **kwargs):
        self.x += distance
        
    def move_south(self, distance, *args, **kwargs):
        self.y -= distance
    
    def move_west(self, distance, *args, **kwargs):
        self.x -= distance
    
    
class Ship:
    def __init__(self, fp="input_12.txt"):
        self.navigations = self._load_data(fp)
        
        self.x = 0
        self.y = 0
        
        self.waypoint = WayPoint(10, 1)
    
    @staticmethod
    def _load_data(fp):
        with open(fp, "r") as f:
            data = [(l[0], int(l[1:])) for l in f.read().split("\n") if l]
        return data
            
    def move_forward(self, distance, *args, **kwargs):
        x_distance = distance * self.waypoint.x
        y_distance = distance * self.waypoint.y
        
        self.x += x_distance
        self.y += y_distance
    
    def navigate(self, instruction, value):
        move_dict = {
            "N": self.waypoint.move_north,
            "S": self.waypoint.move_south,
            "E": self.waypoint.move_east,
            "W": self.waypoint.move_west,
            "L": self.waypoint.rotate,
            "R": self.waypoint.rotate,
            "F": self.move_forward
        }
        move_dict[instruction](value, self.x, self.y, instruction)
    
    def eval_position(self):
        for instruction in self.navigations:
            print(f"SHIP: [{self.x}, {self.y}], WAYPOINT: [{self.waypoint.x}, {self.waypoint.y}]")
            print(instruction)
            self.navigate(*instruction)
        print(f"SHIP: [{self.x}, {self.y}], WAYPOINT: [{self.waypoint.x}, {self.waypoint.y}]")

    @property 
    def manhattan_distance(self):
        return int(abs(self.x) + abs(self.y))

# %%
# s = Ship("test_input_12.txt")
s = Ship()
s.eval_position()
# Out:
# SHIP: [0, 0], WAYPOINT: [10, 1]
# ('W', 4)
# SHIP: [0, 0], WAYPOINT: [6, 1]
# ('N', 1)
# SHIP: [0, 0], WAYPOINT: [6, 2]
# ('F', 35)
# SHIP: [210, 70], WAYPOINT: [6, 2]
# ('R', 90)
# SHIP: [210, 70], WAYPOINT: [2, -6]
# ('F', 2)
# SHIP: [214, 58], WAYPOINT: [2, -6]
# ('N', 3)
# SHIP: [214, 58], WAYPOINT: [2, -3]
# ('W', 4)
# SHIP: [214, 58], WAYPOINT: [-2, -3]
# ('S', 1)
# SHIP: [214, 58], WAYPOINT: [-2, -4]
# ('R', 90)
# SHIP: [214, 58], WAYPOINT: [-4, 2]
# ('F', 89)
# SHIP: [-142, 236], WAYPOINT: [-4, 2]
# ('W', 3)
# SHIP: [-142, 236], WAYPOINT: [-7, 2]
# ('N', 3)
# SHIP: [-142, 236], WAYPOINT: [-7, 5]
# ('R', 90)
# SHIP: [-142, 236], WAYPOINT: [5, 7]
# ('W', 5)
# SHIP: [-142, 236], WAYPOINT: [0, 7]
# ('F', 46)
# SHIP: [-142, 558], WAYPOINT: [0, 7]
# ('L', 90)
# SHIP: [-142, 558], WAYPOINT: [-7, 0]
# ('W', 5)
# SHIP: [-142, 558], WAYPOINT: [-12, 0]
# ('L', 90)
# SHIP: [-142, 558], WAYPOINT: [0, -12]
# ('F', 15)
# SHIP: [-142, 378], WAYPOINT: [0, -12]
# ('W', 5)
# SHIP: [-142, 378], WAYPOINT: [-5, -12]
# ('N', 5)
# SHIP: [-142, 378], WAYPOINT: [-5, -7]
# ('E', 1)
# SHIP: [-142, 378], WAYPOINT: [-4, -7]
# ('F', 92)
# SHIP: [-510, -266], WAYPOINT: [-4, -7]
# ('N', 2)
# SHIP: [-510, -266], WAYPOINT: [-4, -5]
# ('W', 5)
# SHIP: [-510, -266], WAYPOINT: [-9, -5]
# ('L', 180)
# SHIP: [-510, -266], WAYPOINT: [9, 5]
# ('F', 27)
# SHIP: [-267, -131], WAYPOINT: [9, 5]
# ('N', 4)
# SHIP: [-267, -131], WAYPOINT: [9, 9]
# ('F', 32)
# SHIP: [21, 157], WAYPOINT: [9, 9]
# ('R', 90)
# SHIP: [21, 157], WAYPOINT: [9, -9]
# ('S', 5)
# SHIP: [21, 157], WAYPOINT: [9, -14]
# ('F', 12)
# SHIP: [129, -11], WAYPOINT: [9, -14]
# ('E', 3)
# SHIP: [129, -11], WAYPOINT: [12, -14]
# ('R', 90)
# SHIP: [129, -11], WAYPOINT: [-14, -12]
# ('N', 2)
# SHIP: [129, -11], WAYPOINT: [-14, -10]
# ('F', 54)
# SHIP: [-627, -551], WAYPOINT: [-14, -10]
# ('R', 180)
# SHIP: [-627, -551], WAYPOINT: [14, 10]
# ('E', 2)
# SHIP: [-627, -551], WAYPOINT: [16, 10]
# ('L', 90)
# SHIP: [-627, -551], WAYPOINT: [-10, 16]
# ('E', 1)
# SHIP: [-627, -551], WAYPOINT: [-9, 16]
# ('R', 180)
# SHIP: [-627, -551], WAYPOINT: [9, -16]
# ('F', 98)
# SHIP: [255, -2119], WAYPOINT: [9, -16]
# ('N', 5)
# SHIP: [255, -2119], WAYPOINT: [9, -11]
# ('F', 41)
# SHIP: [624, -2570], WAYPOINT: [9, -11]
# ('S', 1)
# SHIP: [624, -2570], WAYPOINT: [9, -12]
# ('R', 180)
# SHIP: [624, -2570], WAYPOINT: [-9, 12]
# ('N', 5)
# SHIP: [624, -2570], WAYPOINT: [-9, 17]
# ('F', 24)
# SHIP: [408, -2162], WAYPOINT: [-9, 17]
# ('W', 5)
# SHIP: [408, -2162], WAYPOINT: [-14, 17]
# ('R', 90)
# SHIP: [408, -2162], WAYPOINT: [17, 14]
# ('S', 4)
# SHIP: [408, -2162], WAYPOINT: [17, 10]
# ('R', 180)
# SHIP: [408, -2162], WAYPOINT: [-17, -10]
# ('W', 4)
# SHIP: [408, -2162], WAYPOINT: [-21, -10]
# ('R', 90)
# SHIP: [408, -2162], WAYPOINT: [-10, 21]
# ('W', 3)
# SHIP: [408, -2162], WAYPOINT: [-13, 21]
# ('N', 5)
# SHIP: [408, -2162], WAYPOINT: [-13, 26]
# ('E', 2)
# SHIP: [408, -2162], WAYPOINT: [-11, 26]
# ('F', 69)
# SHIP: [-351, -368], WAYPOINT: [-11, 26]
# ('N', 2)
# SHIP: [-351, -368], WAYPOINT: [-11, 28]
# ('R', 180)
# SHIP: [-351, -368], WAYPOINT: [11, -28]
# ('F', 48)
# SHIP: [177, -1712], WAYPOINT: [11, -28]
# ('W', 2)
# SHIP: [177, -1712], WAYPOINT: [9, -28]
# ('N', 4)
# SHIP: [177, -1712], WAYPOINT: [9, -24]
# ('E', 5)
# SHIP: [177, -1712], WAYPOINT: [14, -24]
# ('S', 1)
# SHIP: [177, -1712], WAYPOINT: [14, -25]
# ('W', 1)
# SHIP: [177, -1712], WAYPOINT: [13, -25]
# ('F', 39)
# SHIP: [684, -2687], WAYPOINT: [13, -25]
# ('S', 5)
# SHIP: [684, -2687], WAYPOINT: [13, -30]
# ('L', 90)
# SHIP: [684, -2687], WAYPOINT: [30, 13]
# ('E', 4)
# SHIP: [684, -2687], WAYPOINT: [34, 13]
# ('R', 180)
# SHIP: [684, -2687], WAYPOINT: [-34, -13]
# ('E', 4)
# SHIP: [684, -2687], WAYPOINT: [-30, -13]
# ('L', 180)
# SHIP: [684, -2687], WAYPOINT: [30, 13]
# ('E', 1)
# SHIP: [684, -2687], WAYPOINT: [31, 13]
# ('R', 90)
# SHIP: [684, -2687], WAYPOINT: [13, -31]
# ('F', 97)
# SHIP: [1945, -5694], WAYPOINT: [13, -31]
# ('S', 2)
# SHIP: [1945, -5694], WAYPOINT: [13, -33]
# ('L', 270)
# SHIP: [1945, -5694], WAYPOINT: [-33, -13]
# ('N', 5)
# SHIP: [1945, -5694], WAYPOINT: [-33, -8]
# ('E', 2)
# SHIP: [1945, -5694], WAYPOINT: [-31, -8]
# ('R', 90)
# SHIP: [1945, -5694], WAYPOINT: [-8, 31]
# ('S', 1)
# SHIP: [1945, -5694], WAYPOINT: [-8, 30]
# ('R', 90)
# SHIP: [1945, -5694], WAYPOINT: [30, 8]
# ('E', 4)
# SHIP: [1945, -5694], WAYPOINT: [34, 8]
# ('N', 4)
# SHIP: [1945, -5694], WAYPOINT: [34, 12]
# ('F', 2)
# SHIP: [2013, -5670], WAYPOINT: [34, 12]
# ('N', 3)
# SHIP: [2013, -5670], WAYPOINT: [34, 15]
# ('L', 90)
# SHIP: [2013, -5670], WAYPOINT: [-15, 34]
# ('E', 4)
# SHIP: [2013, -5670], WAYPOINT: [-11, 34]
# ('F', 84)
# SHIP: [1089, -2814], WAYPOINT: [-11, 34]
# ('W', 5)
# SHIP: [1089, -2814], WAYPOINT: [-16, 34]
# ('N', 2)
# SHIP: [1089, -2814], WAYPOINT: [-16, 36]
# ('E', 4)
# SHIP: [1089, -2814], WAYPOINT: [-12, 36]
# ('S', 2)
# SHIP: [1089, -2814], WAYPOINT: [-12, 34]
# ('E', 1)
# SHIP: [1089, -2814], WAYPOINT: [-11, 34]
# ('S', 5)
# SHIP: [1089, -2814], WAYPOINT: [-11, 29]
# ('E', 2)
# SHIP: [1089, -2814], WAYPOINT: [-9, 29]
# ('N', 4)
# SHIP: [1089, -2814], WAYPOINT: [-9, 33]
# ('E', 1)
# SHIP: [1089, -2814], WAYPOINT: [-8, 33]
# ('F', 94)
# SHIP: [337, 288], WAYPOINT: [-8, 33]
# ('R', 180)
# SHIP: [337, 288], WAYPOINT: [8, -33]
# ('N', 2)
# SHIP: [337, 288], WAYPOINT: [8, -31]
# ('L', 90)
# SHIP: [337, 288], WAYPOINT: [31, 8]
# ('W', 4)
# SHIP: [337, 288], WAYPOINT: [27, 8]
# ('L', 180)
# SHIP: [337, 288], WAYPOINT: [-27, -8]
# ('F', 82)
# SHIP: [-1877, -368], WAYPOINT: [-27, -8]
# ('E', 1)
# SHIP: [-1877, -368], WAYPOINT: [-26, -8]
# ('L', 270)
# SHIP: [-1877, -368], WAYPOINT: [-8, 26]
# ('F', 14)
# SHIP: [-1989, -4], WAYPOINT: [-8, 26]
# ('S', 5)
# SHIP: [-1989, -4], WAYPOINT: [-8, 21]
# ('S', 5)
# SHIP: [-1989, -4], WAYPOINT: [-8, 16]
# ('R', 90)
# SHIP: [-1989, -4], WAYPOINT: [16, 8]
# ('F', 75)
# SHIP: [-789, 596], WAYPOINT: [16, 8]
# ('R', 90)
# SHIP: [-789, 596], WAYPOINT: [8, -16]
# ('E', 5)
# SHIP: [-789, 596], WAYPOINT: [13, -16]
# ('S', 3)
# SHIP: [-789, 596], WAYPOINT: [13, -19]
# ('R', 90)
# SHIP: [-789, 596], WAYPOINT: [-19, -13]
# ('N', 2)
# SHIP: [-789, 596], WAYPOINT: [-19, -11]
# ('F', 94)
# SHIP: [-2575, -438], WAYPOINT: [-19, -11]
# ('L', 180)
# SHIP: [-2575, -438], WAYPOINT: [19, 11]
# ('E', 4)
# SHIP: [-2575, -438], WAYPOINT: [23, 11]
# ('F', 3)
# SHIP: [-2506, -405], WAYPOINT: [23, 11]
# ('E', 5)
# SHIP: [-2506, -405], WAYPOINT: [28, 11]
# ('N', 3)
# SHIP: [-2506, -405], WAYPOINT: [28, 14]
# ('R', 90)
# SHIP: [-2506, -405], WAYPOINT: [14, -28]
# ('N', 1)
# SHIP: [-2506, -405], WAYPOINT: [14, -27]
# ('E', 1)
# SHIP: [-2506, -405], WAYPOINT: [15, -27]
# ('S', 1)
# SHIP: [-2506, -405], WAYPOINT: [15, -28]
# ('R', 90)
# SHIP: [-2506, -405], WAYPOINT: [-28, -15]
# ('N', 4)
# SHIP: [-2506, -405], WAYPOINT: [-28, -11]
# ('L', 90)
# SHIP: [-2506, -405], WAYPOINT: [11, -28]
# ('E', 3)
# SHIP: [-2506, -405], WAYPOINT: [14, -28]
# ('L', 270)
# SHIP: [-2506, -405], WAYPOINT: [-28, -14]
# ('F', 45)
# SHIP: [-3766, -1035], WAYPOINT: [-28, -14]
# ('E', 2)
# SHIP: [-3766, -1035], WAYPOINT: [-26, -14]
# ('S', 2)
# SHIP: [-3766, -1035], WAYPOINT: [-26, -16]
# ('E', 1)
# SHIP: [-3766, -1035], WAYPOINT: [-25, -16]
# ('F', 67)
# SHIP: [-5441, -2107], WAYPOINT: [-25, -16]
# ('L', 90)
# SHIP: [-5441, -2107], WAYPOINT: [16, -25]
# ('F', 15)
# SHIP: [-5201, -2482], WAYPOINT: [16, -25]
# ('N', 3)
# SHIP: [-5201, -2482], WAYPOINT: [16, -22]
# ('W', 4)
# SHIP: [-5201, -2482], WAYPOINT: [12, -22]
# ('N', 3)
# SHIP: [-5201, -2482], WAYPOINT: [12, -19]
# ('R', 90)
# SHIP: [-5201, -2482], WAYPOINT: [-19, -12]
# ('F', 51)
# SHIP: [-6170, -3094], WAYPOINT: [-19, -12]
# ('N', 3)
# SHIP: [-6170, -3094], WAYPOINT: [-19, -9]
# ('S', 2)
# SHIP: [-6170, -3094], WAYPOINT: [-19, -11]
# ('R', 90)
# SHIP: [-6170, -3094], WAYPOINT: [-11, 19]
# ('N', 1)
# SHIP: [-6170, -3094], WAYPOINT: [-11, 20]
# ('L', 180)
# SHIP: [-6170, -3094], WAYPOINT: [11, -20]
# ('W', 3)
# SHIP: [-6170, -3094], WAYPOINT: [8, -20]
# ('L', 90)
# SHIP: [-6170, -3094], WAYPOINT: [20, 8]
# ('W', 5)
# SHIP: [-6170, -3094], WAYPOINT: [15, 8]
# ('F', 8)
# SHIP: [-6050, -3030], WAYPOINT: [15, 8]
# ('N', 3)
# SHIP: [-6050, -3030], WAYPOINT: [15, 11]
# ('F', 36)
# SHIP: [-5510, -2634], WAYPOINT: [15, 11]
# ('N', 2)
# SHIP: [-5510, -2634], WAYPOINT: [15, 13]
# ('L', 90)
# SHIP: [-5510, -2634], WAYPOINT: [-13, 15]
# ('S', 4)
# SHIP: [-5510, -2634], WAYPOINT: [-13, 11]
# ('F', 91)
# SHIP: [-6693, -1633], WAYPOINT: [-13, 11]
# ('N', 1)
# SHIP: [-6693, -1633], WAYPOINT: [-13, 12]
# ('E', 4)
# SHIP: [-6693, -1633], WAYPOINT: [-9, 12]
# ('R', 90)
# SHIP: [-6693, -1633], WAYPOINT: [12, 9]
# ('E', 5)
# SHIP: [-6693, -1633], WAYPOINT: [17, 9]
# ('L', 90)
# SHIP: [-6693, -1633], WAYPOINT: [-9, 17]
# ('E', 2)
# SHIP: [-6693, -1633], WAYPOINT: [-7, 17]
# ('F', 77)
# SHIP: [-7232, -324], WAYPOINT: [-7, 17]
# ('R', 90)
# SHIP: [-7232, -324], WAYPOINT: [17, 7]
# ('E', 4)
# SHIP: [-7232, -324], WAYPOINT: [21, 7]
# ('F', 8)
# SHIP: [-7064, -268], WAYPOINT: [21, 7]
# ('W', 2)
# SHIP: [-7064, -268], WAYPOINT: [19, 7]
# ('R', 90)
# SHIP: [-7064, -268], WAYPOINT: [7, -19]
# ('N', 5)
# SHIP: [-7064, -268], WAYPOINT: [7, -14]
# ('R', 90)
# SHIP: [-7064, -268], WAYPOINT: [-14, -7]
# ('E', 5)
# SHIP: [-7064, -268], WAYPOINT: [-9, -7]
# ('S', 4)
# SHIP: [-7064, -268], WAYPOINT: [-9, -11]
# ('W', 5)
# SHIP: [-7064, -268], WAYPOINT: [-14, -11]
# ('F', 68)
# SHIP: [-8016, -1016], WAYPOINT: [-14, -11]
# ('N', 1)
# SHIP: [-8016, -1016], WAYPOINT: [-14, -10]
# ('F', 72)
# SHIP: [-9024, -1736], WAYPOINT: [-14, -10]
# ('S', 3)
# SHIP: [-9024, -1736], WAYPOINT: [-14, -13]
# ('W', 3)
# SHIP: [-9024, -1736], WAYPOINT: [-17, -13]
# ('F', 36)
# SHIP: [-9636, -2204], WAYPOINT: [-17, -13]
# ('E', 5)
# SHIP: [-9636, -2204], WAYPOINT: [-12, -13]
# ('F', 53)
# SHIP: [-10272, -2893], WAYPOINT: [-12, -13]
# ('E', 1)
# SHIP: [-10272, -2893], WAYPOINT: [-11, -13]
# ('E', 1)
# SHIP: [-10272, -2893], WAYPOINT: [-10, -13]
# ('N', 3)
# SHIP: [-10272, -2893], WAYPOINT: [-10, -10]
# ('W', 3)
# SHIP: [-10272, -2893], WAYPOINT: [-13, -10]
# ('N', 5)
# SHIP: [-10272, -2893], WAYPOINT: [-13, -5]
# ('L', 270)
# SHIP: [-10272, -2893], WAYPOINT: [-5, 13]
# ('S', 2)
# SHIP: [-10272, -2893], WAYPOINT: [-5, 11]
# ('L', 180)
# SHIP: [-10272, -2893], WAYPOINT: [5, -11]
# ('E', 3)
# SHIP: [-10272, -2893], WAYPOINT: [8, -11]
# ('S', 2)
# SHIP: [-10272, -2893], WAYPOINT: [8, -13]
# ('W', 1)
# SHIP: [-10272, -2893], WAYPOINT: [7, -13]
# ('R', 90)
# SHIP: [-10272, -2893], WAYPOINT: [-13, -7]
# ('E', 5)
# SHIP: [-10272, -2893], WAYPOINT: [-8, -7]
# ('S', 1)
# SHIP: [-10272, -2893], WAYPOINT: [-8, -8]
# ('W', 5)
# SHIP: [-10272, -2893], WAYPOINT: [-13, -8]
# ('N', 1)
# SHIP: [-10272, -2893], WAYPOINT: [-13, -7]
# ('F', 16)
# SHIP: [-10480, -3005], WAYPOINT: [-13, -7]
# ('W', 5)
# SHIP: [-10480, -3005], WAYPOINT: [-18, -7]
# ('N', 2)
# SHIP: [-10480, -3005], WAYPOINT: [-18, -5]
# ('E', 2)
# SHIP: [-10480, -3005], WAYPOINT: [-16, -5]
# ('N', 3)
# SHIP: [-10480, -3005], WAYPOINT: [-16, -2]
# ('F', 9)
# SHIP: [-10624, -3023], WAYPOINT: [-16, -2]
# ('S', 3)
# SHIP: [-10624, -3023], WAYPOINT: [-16, -5]
# ('L', 180)
# SHIP: [-10624, -3023], WAYPOINT: [16, 5]
# ('F', 33)
# SHIP: [-10096, -2858], WAYPOINT: [16, 5]
# ('E', 2)
# SHIP: [-10096, -2858], WAYPOINT: [18, 5]
# ('L', 90)
# SHIP: [-10096, -2858], WAYPOINT: [-5, 18]
# ('R', 90)
# SHIP: [-10096, -2858], WAYPOINT: [18, 5]
# ('F', 13)
# SHIP: [-9862, -2793], WAYPOINT: [18, 5]
# ('S', 4)
# SHIP: [-9862, -2793], WAYPOINT: [18, 1]
# ('W', 3)
# SHIP: [-9862, -2793], WAYPOINT: [15, 1]
# ('S', 5)
# SHIP: [-9862, -2793], WAYPOINT: [15, -4]
# ('F', 71)
# SHIP: [-8797, -3077], WAYPOINT: [15, -4]
# ('N', 1)
# SHIP: [-8797, -3077], WAYPOINT: [15, -3]
# ('S', 2)
# SHIP: [-8797, -3077], WAYPOINT: [15, -5]
# ('F', 49)
# SHIP: [-8062, -3322], WAYPOINT: [15, -5]
# ('E', 5)
# SHIP: [-8062, -3322], WAYPOINT: [20, -5]
# ('F', 3)
# SHIP: [-8002, -3337], WAYPOINT: [20, -5]
# ('S', 3)
# SHIP: [-8002, -3337], WAYPOINT: [20, -8]
# ('L', 270)
# SHIP: [-8002, -3337], WAYPOINT: [-8, -20]
# ('N', 4)
# SHIP: [-8002, -3337], WAYPOINT: [-8, -16]
# ('E', 3)
# SHIP: [-8002, -3337], WAYPOINT: [-5, -16]
# ('R', 270)
# SHIP: [-8002, -3337], WAYPOINT: [16, -5]
# ('N', 2)
# SHIP: [-8002, -3337], WAYPOINT: [16, -3]
# ('L', 90)
# SHIP: [-8002, -3337], WAYPOINT: [3, 16]
# ('F', 96)
# SHIP: [-7714, -1801], WAYPOINT: [3, 16]
# ('S', 3)
# SHIP: [-7714, -1801], WAYPOINT: [3, 13]
# ('R', 180)
# SHIP: [-7714, -1801], WAYPOINT: [-3, -13]
# ('F', 48)
# SHIP: [-7858, -2425], WAYPOINT: [-3, -13]
# ('E', 3)
# SHIP: [-7858, -2425], WAYPOINT: [0, -13]
# ('N', 3)
# SHIP: [-7858, -2425], WAYPOINT: [0, -10]
# ('F', 2)
# SHIP: [-7858, -2445], WAYPOINT: [0, -10]
# ('E', 1)
# SHIP: [-7858, -2445], WAYPOINT: [1, -10]
# ('S', 5)
# SHIP: [-7858, -2445], WAYPOINT: [1, -15]
# ('F', 88)
# SHIP: [-7770, -3765], WAYPOINT: [1, -15]
# ('W', 4)
# SHIP: [-7770, -3765], WAYPOINT: [-3, -15]
# ('F', 98)
# SHIP: [-8064, -5235], WAYPOINT: [-3, -15]
# ('E', 5)
# SHIP: [-8064, -5235], WAYPOINT: [2, -15]
# ('F', 45)
# SHIP: [-7974, -5910], WAYPOINT: [2, -15]
# ('R', 90)
# SHIP: [-7974, -5910], WAYPOINT: [-15, -2]
# ('N', 5)
# SHIP: [-7974, -5910], WAYPOINT: [-15, 3]
# ('W', 5)
# SHIP: [-7974, -5910], WAYPOINT: [-20, 3]
# ('L', 90)
# SHIP: [-7974, -5910], WAYPOINT: [-3, -20]
# ('S', 3)
# SHIP: [-7974, -5910], WAYPOINT: [-3, -23]
# ('E', 1)
# SHIP: [-7974, -5910], WAYPOINT: [-2, -23]
# ('F', 18)
# SHIP: [-8010, -6324], WAYPOINT: [-2, -23]
# ('E', 3)
# SHIP: [-8010, -6324], WAYPOINT: [1, -23]
# ('S', 1)
# SHIP: [-8010, -6324], WAYPOINT: [1, -24]
# ('F', 59)
# SHIP: [-7951, -7740], WAYPOINT: [1, -24]
# ('L', 270)
# SHIP: [-7951, -7740], WAYPOINT: [-24, -1]
# ('N', 4)
# SHIP: [-7951, -7740], WAYPOINT: [-24, 3]
# ('L', 180)
# SHIP: [-7951, -7740], WAYPOINT: [24, -3]
# ('W', 4)
# SHIP: [-7951, -7740], WAYPOINT: [20, -3]
# ('S', 2)
# SHIP: [-7951, -7740], WAYPOINT: [20, -5]
# ('F', 88)
# SHIP: [-6191, -8180], WAYPOINT: [20, -5]
# ('L', 90)
# SHIP: [-6191, -8180], WAYPOINT: [5, 20]
# ('N', 4)
# SHIP: [-6191, -8180], WAYPOINT: [5, 24]
# ('F', 1)
# SHIP: [-6186, -8156], WAYPOINT: [5, 24]
# ('L', 180)
# SHIP: [-6186, -8156], WAYPOINT: [-5, -24]
# ('E', 4)
# SHIP: [-6186, -8156], WAYPOINT: [-1, -24]
# ('L', 90)
# SHIP: [-6186, -8156], WAYPOINT: [24, -1]
# ('W', 4)
# SHIP: [-6186, -8156], WAYPOINT: [20, -1]
# ('R', 180)
# SHIP: [-6186, -8156], WAYPOINT: [-20, 1]
# ('F', 50)
# SHIP: [-7186, -8106], WAYPOINT: [-20, 1]
# ('L', 180)
# SHIP: [-7186, -8106], WAYPOINT: [20, -1]
# ('W', 5)
# SHIP: [-7186, -8106], WAYPOINT: [15, -1]
# ('F', 14)
# SHIP: [-6976, -8120], WAYPOINT: [15, -1]
# ('S', 4)
# SHIP: [-6976, -8120], WAYPOINT: [15, -5]
# ('F', 6)
# SHIP: [-6886, -8150], WAYPOINT: [15, -5]
# ('R', 90)
# SHIP: [-6886, -8150], WAYPOINT: [-5, -15]
# ('E', 1)
# SHIP: [-6886, -8150], WAYPOINT: [-4, -15]
# ('N', 5)
# SHIP: [-6886, -8150], WAYPOINT: [-4, -10]
# ('E', 3)
# SHIP: [-6886, -8150], WAYPOINT: [-1, -10]
# ('F', 51)
# SHIP: [-6937, -8660], WAYPOINT: [-1, -10]
# ('R', 90)
# SHIP: [-6937, -8660], WAYPOINT: [-10, 1]
# ('E', 5)
# SHIP: [-6937, -8660], WAYPOINT: [-5, 1]
# ('R', 90)
# SHIP: [-6937, -8660], WAYPOINT: [1, 5]
# ('F', 78)
# SHIP: [-6859, -8270], WAYPOINT: [1, 5]
# ('S', 1)
# SHIP: [-6859, -8270], WAYPOINT: [1, 4]
# ('W', 4)
# SHIP: [-6859, -8270], WAYPOINT: [-3, 4]
# ('N', 2)
# SHIP: [-6859, -8270], WAYPOINT: [-3, 6]
# ('R', 90)
# SHIP: [-6859, -8270], WAYPOINT: [6, 3]
# ('F', 43)
# SHIP: [-6601, -8141], WAYPOINT: [6, 3]
# ('E', 2)
# SHIP: [-6601, -8141], WAYPOINT: [8, 3]
# ('N', 4)
# SHIP: [-6601, -8141], WAYPOINT: [8, 7]
# ('R', 90)
# SHIP: [-6601, -8141], WAYPOINT: [7, -8]
# ('F', 44)
# SHIP: [-6293, -8493], WAYPOINT: [7, -8]
# ('L', 90)
# SHIP: [-6293, -8493], WAYPOINT: [8, 7]
# ('F', 16)
# SHIP: [-6165, -8381], WAYPOINT: [8, 7]
# ('N', 2)
# SHIP: [-6165, -8381], WAYPOINT: [8, 9]
# ('W', 4)
# SHIP: [-6165, -8381], WAYPOINT: [4, 9]
# ('S', 2)
# SHIP: [-6165, -8381], WAYPOINT: [4, 7]
# ('F', 53)
# SHIP: [-5953, -8010], WAYPOINT: [4, 7]
# ('S', 4)
# SHIP: [-5953, -8010], WAYPOINT: [4, 3]
# ('W', 5)
# SHIP: [-5953, -8010], WAYPOINT: [-1, 3]
# ('F', 30)
# SHIP: [-5983, -7920], WAYPOINT: [-1, 3]
# ('L', 90)
# SHIP: [-5983, -7920], WAYPOINT: [-3, -1]
# ('E', 4)
# SHIP: [-5983, -7920], WAYPOINT: [1, -1]
# ('F', 87)
# SHIP: [-5896, -8007], WAYPOINT: [1, -1]
# ('E', 3)
# SHIP: [-5896, -8007], WAYPOINT: [4, -1]
# ('L', 90)
# SHIP: [-5896, -8007], WAYPOINT: [1, 4]
# ('S', 1)
# SHIP: [-5896, -8007], WAYPOINT: [1, 3]
# ('F', 34)
# SHIP: [-5862, -7905], WAYPOINT: [1, 3]
# ('W', 1)
# SHIP: [-5862, -7905], WAYPOINT: [0, 3]
# ('L', 90)
# SHIP: [-5862, -7905], WAYPOINT: [-3, 0]
# ('F', 74)
# SHIP: [-6084, -7905], WAYPOINT: [-3, 0]
# ('S', 3)
# SHIP: [-6084, -7905], WAYPOINT: [-3, -3]
# ('F', 4)
# SHIP: [-6096, -7917], WAYPOINT: [-3, -3]
# ('E', 4)
# SHIP: [-6096, -7917], WAYPOINT: [1, -3]
# ('N', 2)
# SHIP: [-6096, -7917], WAYPOINT: [1, -1]
# ('F', 34)
# SHIP: [-6062, -7951], WAYPOINT: [1, -1]
# ('W', 1)
# SHIP: [-6062, -7951], WAYPOINT: [0, -1]
# ('L', 180)
# SHIP: [-6062, -7951], WAYPOINT: [0, 1]
# ('F', 57)
# SHIP: [-6062, -7894], WAYPOINT: [0, 1]
# ('E', 3)
# SHIP: [-6062, -7894], WAYPOINT: [3, 1]
# ('R', 90)
# SHIP: [-6062, -7894], WAYPOINT: [1, -3]
# ('W', 4)
# SHIP: [-6062, -7894], WAYPOINT: [-3, -3]
# ('N', 1)
# SHIP: [-6062, -7894], WAYPOINT: [-3, -2]
# ('R', 90)
# SHIP: [-6062, -7894], WAYPOINT: [-2, 3]
# ('E', 3)
# SHIP: [-6062, -7894], WAYPOINT: [1, 3]
# ('R', 180)
# SHIP: [-6062, -7894], WAYPOINT: [-1, -3]
# ('F', 51)
# SHIP: [-6113, -8047], WAYPOINT: [-1, -3]
# ('S', 2)
# SHIP: [-6113, -8047], WAYPOINT: [-1, -5]
# ('R', 90)
# SHIP: [-6113, -8047], WAYPOINT: [-5, 1]
# ('S', 1)
# SHIP: [-6113, -8047], WAYPOINT: [-5, 0]
# ('E', 4)
# SHIP: [-6113, -8047], WAYPOINT: [-1, 0]
# ('S', 4)
# SHIP: [-6113, -8047], WAYPOINT: [-1, -4]
# ('F', 19)
# SHIP: [-6132, -8123], WAYPOINT: [-1, -4]
# ('W', 3)
# SHIP: [-6132, -8123], WAYPOINT: [-4, -4]
# ('F', 64)
# SHIP: [-6388, -8379], WAYPOINT: [-4, -4]
# ('E', 3)
# SHIP: [-6388, -8379], WAYPOINT: [-1, -4]
# ('N', 1)
# SHIP: [-6388, -8379], WAYPOINT: [-1, -3]
# ('E', 2)
# SHIP: [-6388, -8379], WAYPOINT: [1, -3]
# ('L', 90)
# SHIP: [-6388, -8379], WAYPOINT: [3, 1]
# ('E', 3)
# SHIP: [-6388, -8379], WAYPOINT: [6, 1]
# ('W', 1)
# SHIP: [-6388, -8379], WAYPOINT: [5, 1]
# ('S', 3)
# SHIP: [-6388, -8379], WAYPOINT: [5, -2]
# ('R', 90)
# SHIP: [-6388, -8379], WAYPOINT: [-2, -5]
# ('F', 81)
# SHIP: [-6550, -8784], WAYPOINT: [-2, -5]
# ('E', 3)
# SHIP: [-6550, -8784], WAYPOINT: [1, -5]
# ('S', 5)
# SHIP: [-6550, -8784], WAYPOINT: [1, -10]
# ('R', 90)
# SHIP: [-6550, -8784], WAYPOINT: [-10, -1]
# ('F', 11)
# SHIP: [-6660, -8795], WAYPOINT: [-10, -1]
# ('R', 90)
# SHIP: [-6660, -8795], WAYPOINT: [-1, 10]
# ('W', 4)
# SHIP: [-6660, -8795], WAYPOINT: [-5, 10]
# ('N', 5)
# SHIP: [-6660, -8795], WAYPOINT: [-5, 15]
# ('W', 2)
# SHIP: [-6660, -8795], WAYPOINT: [-7, 15]
# ('S', 4)
# SHIP: [-6660, -8795], WAYPOINT: [-7, 11]
# ('W', 1)
# SHIP: [-6660, -8795], WAYPOINT: [-8, 11]
# ('S', 4)
# SHIP: [-6660, -8795], WAYPOINT: [-8, 7]
# ('F', 70)
# SHIP: [-7220, -8305], WAYPOINT: [-8, 7]
# ('L', 180)
# SHIP: [-7220, -8305], WAYPOINT: [8, -7]
# ('F', 75)
# SHIP: [-6620, -8830], WAYPOINT: [8, -7]
# ('F', 55)
# SHIP: [-6180, -9215], WAYPOINT: [8, -7]
# ('S', 2)
# SHIP: [-6180, -9215], WAYPOINT: [8, -9]
# ('W', 3)
# SHIP: [-6180, -9215], WAYPOINT: [5, -9]
# ('S', 1)
# SHIP: [-6180, -9215], WAYPOINT: [5, -10]
# ('L', 90)
# SHIP: [-6180, -9215], WAYPOINT: [10, 5]
# ('E', 3)
# SHIP: [-6180, -9215], WAYPOINT: [13, 5]
# ('L', 90)
# SHIP: [-6180, -9215], WAYPOINT: [-5, 13]
# ('W', 1)
# SHIP: [-6180, -9215], WAYPOINT: [-6, 13]
# ('F', 41)
# SHIP: [-6426, -8682], WAYPOINT: [-6, 13]
# ('S', 3)
# SHIP: [-6426, -8682], WAYPOINT: [-6, 10]
# ('L', 90)
# SHIP: [-6426, -8682], WAYPOINT: [-10, -6]
# ('N', 5)
# SHIP: [-6426, -8682], WAYPOINT: [-10, -1]
# ('L', 90)
# SHIP: [-6426, -8682], WAYPOINT: [1, -10]
# ('W', 4)
# SHIP: [-6426, -8682], WAYPOINT: [-3, -10]
# ('F', 6)
# SHIP: [-6444, -8742], WAYPOINT: [-3, -10]
# ('R', 180)
# SHIP: [-6444, -8742], WAYPOINT: [3, 10]
# ('E', 4)
# SHIP: [-6444, -8742], WAYPOINT: [7, 10]
# ('F', 37)
# SHIP: [-6185, -8372], WAYPOINT: [7, 10]
# ('L', 90)
# SHIP: [-6185, -8372], WAYPOINT: [-10, 7]
# ('F', 68)
# SHIP: [-6865, -7896], WAYPOINT: [-10, 7]
# ('R', 90)
# SHIP: [-6865, -7896], WAYPOINT: [7, 10]
# ('W', 3)
# SHIP: [-6865, -7896], WAYPOINT: [4, 10]
# ('F', 82)
# SHIP: [-6537, -7076], WAYPOINT: [4, 10]
# ('S', 5)
# SHIP: [-6537, -7076], WAYPOINT: [4, 5]
# ('L', 270)
# SHIP: [-6537, -7076], WAYPOINT: [5, -4]
# ('S', 5)
# SHIP: [-6537, -7076], WAYPOINT: [5, -9]
# ('F', 86)
# SHIP: [-6107, -7850], WAYPOINT: [5, -9]
# ('L', 90)
# SHIP: [-6107, -7850], WAYPOINT: [9, 5]
# ('F', 44)
# SHIP: [-5711, -7630], WAYPOINT: [9, 5]
# ('R', 90)
# SHIP: [-5711, -7630], WAYPOINT: [5, -9]
# ('W', 4)
# SHIP: [-5711, -7630], WAYPOINT: [1, -9]
# ('R', 180)
# SHIP: [-5711, -7630], WAYPOINT: [-1, 9]
# ('S', 3)
# SHIP: [-5711, -7630], WAYPOINT: [-1, 6]
# ('F', 73)
# SHIP: [-5784, -7192], WAYPOINT: [-1, 6]
# ('L', 90)
# SHIP: [-5784, -7192], WAYPOINT: [-6, -1]
# ('E', 5)
# SHIP: [-5784, -7192], WAYPOINT: [-1, -1]
# ('R', 90)
# SHIP: [-5784, -7192], WAYPOINT: [-1, 1]
# ('E', 1)
# SHIP: [-5784, -7192], WAYPOINT: [0, 1]
# ('S', 3)
# SHIP: [-5784, -7192], WAYPOINT: [0, -2]
# ('L', 90)
# SHIP: [-5784, -7192], WAYPOINT: [2, 0]
# ('F', 15)
# SHIP: [-5754, -7192], WAYPOINT: [2, 0]
# ('R', 90)
# SHIP: [-5754, -7192], WAYPOINT: [0, -2]
# ('F', 84)
# SHIP: [-5754, -7360], WAYPOINT: [0, -2]
# ('L', 90)
# SHIP: [-5754, -7360], WAYPOINT: [2, 0]
# ('R', 90)
# SHIP: [-5754, -7360], WAYPOINT: [0, -2]
# ('S', 4)
# SHIP: [-5754, -7360], WAYPOINT: [0, -6]
# ('W', 2)
# SHIP: [-5754, -7360], WAYPOINT: [-2, -6]
# ('E', 3)
# SHIP: [-5754, -7360], WAYPOINT: [1, -6]
# ('R', 180)
# SHIP: [-5754, -7360], WAYPOINT: [-1, 6]
# ('F', 29)
# SHIP: [-5783, -7186], WAYPOINT: [-1, 6]
# ('R', 90)
# SHIP: [-5783, -7186], WAYPOINT: [6, 1]
# ('W', 2)
# SHIP: [-5783, -7186], WAYPOINT: [4, 1]
# ('F', 28)
# SHIP: [-5671, -7158], WAYPOINT: [4, 1]
# ('N', 4)
# SHIP: [-5671, -7158], WAYPOINT: [4, 5]
# ('E', 2)
# SHIP: [-5671, -7158], WAYPOINT: [6, 5]
# ('N', 2)
# SHIP: [-5671, -7158], WAYPOINT: [6, 7]
# ('F', 66)
# SHIP: [-5275, -6696], WAYPOINT: [6, 7]
# ('R', 90)
# SHIP: [-5275, -6696], WAYPOINT: [7, -6]
# ('E', 5)
# SHIP: [-5275, -6696], WAYPOINT: [12, -6]
# ('R', 90)
# SHIP: [-5275, -6696], WAYPOINT: [-6, -12]
# ('L', 270)
# SHIP: [-5275, -6696], WAYPOINT: [-12, 6]
# ('S', 1)
# SHIP: [-5275, -6696], WAYPOINT: [-12, 5]
# ('F', 34)
# SHIP: [-5683, -6526], WAYPOINT: [-12, 5]
# ('E', 3)
# SHIP: [-5683, -6526], WAYPOINT: [-9, 5]
# ('S', 3)
# SHIP: [-5683, -6526], WAYPOINT: [-9, 2]
# ('F', 57)
# SHIP: [-6196, -6412], WAYPOINT: [-9, 2]
# ('N', 4)
# SHIP: [-6196, -6412], WAYPOINT: [-9, 6]
# ('S', 4)
# SHIP: [-6196, -6412], WAYPOINT: [-9, 2]
# ('F', 27)
# SHIP: [-6439, -6358], WAYPOINT: [-9, 2]
# ('N', 4)
# SHIP: [-6439, -6358], WAYPOINT: [-9, 6]
# ('W', 5)
# SHIP: [-6439, -6358], WAYPOINT: [-14, 6]
# ('L', 180)
# SHIP: [-6439, -6358], WAYPOINT: [14, -6]
# ('E', 1)
# SHIP: [-6439, -6358], WAYPOINT: [15, -6]
# ('S', 2)
# SHIP: [-6439, -6358], WAYPOINT: [15, -8]
# ('F', 8)
# SHIP: [-6319, -6422], WAYPOINT: [15, -8]
# ('S', 4)
# SHIP: [-6319, -6422], WAYPOINT: [15, -12]
# ('E', 5)
# SHIP: [-6319, -6422], WAYPOINT: [20, -12]
# ('L', 180)
# SHIP: [-6319, -6422], WAYPOINT: [-20, 12]
# ('F', 40)
# SHIP: [-7119, -5942], WAYPOINT: [-20, 12]
# ('L', 90)
# SHIP: [-7119, -5942], WAYPOINT: [-12, -20]
# ('N', 5)
# SHIP: [-7119, -5942], WAYPOINT: [-12, -15]
# ('W', 5)
# SHIP: [-7119, -5942], WAYPOINT: [-17, -15]
# ('N', 2)
# SHIP: [-7119, -5942], WAYPOINT: [-17, -13]
# ('L', 270)
# SHIP: [-7119, -5942], WAYPOINT: [-13, 17]
# ('F', 9)
# SHIP: [-7236, -5789], WAYPOINT: [-13, 17]
# ('E', 5)
# SHIP: [-7236, -5789], WAYPOINT: [-8, 17]
# ('N', 2)
# SHIP: [-7236, -5789], WAYPOINT: [-8, 19]
# ('E', 2)
# SHIP: [-7236, -5789], WAYPOINT: [-6, 19]
# ('L', 90)
# SHIP: [-7236, -5789], WAYPOINT: [-19, -6]
# ('N', 4)
# SHIP: [-7236, -5789], WAYPOINT: [-19, -2]
# ('R', 90)
# SHIP: [-7236, -5789], WAYPOINT: [-2, 19]
# ('S', 2)
# SHIP: [-7236, -5789], WAYPOINT: [-2, 17]
# ('E', 2)
# SHIP: [-7236, -5789], WAYPOINT: [0, 17]
# ('F', 70)
# SHIP: [-7236, -4599], WAYPOINT: [0, 17]
# ('E', 1)
# SHIP: [-7236, -4599], WAYPOINT: [1, 17]
# ('N', 2)
# SHIP: [-7236, -4599], WAYPOINT: [1, 19]
# ('F', 100)
# SHIP: [-7136, -2699], WAYPOINT: [1, 19]
# ('L', 90)
# SHIP: [-7136, -2699], WAYPOINT: [-19, 1]
# ('E', 1)
# SHIP: [-7136, -2699], WAYPOINT: [-18, 1]
# ('F', 59)
# SHIP: [-8198, -2640], WAYPOINT: [-18, 1]
# ('L', 180)
# SHIP: [-8198, -2640], WAYPOINT: [18, -1]
# ('E', 3)
# SHIP: [-8198, -2640], WAYPOINT: [21, -1]
# ('S', 3)
# SHIP: [-8198, -2640], WAYPOINT: [21, -4]
# ('L', 180)
# SHIP: [-8198, -2640], WAYPOINT: [-21, 4]
# ('F', 97)
# SHIP: [-10235, -2252], WAYPOINT: [-21, 4]
# ('W', 1)
# SHIP: [-10235, -2252], WAYPOINT: [-22, 4]
# ('F', 61)
# SHIP: [-11577, -2008], WAYPOINT: [-22, 4]
# ('S', 1)
# SHIP: [-11577, -2008], WAYPOINT: [-22, 3]
# ('E', 2)
# SHIP: [-11577, -2008], WAYPOINT: [-20, 3]
# ('N', 3)
# SHIP: [-11577, -2008], WAYPOINT: [-20, 6]
# ('R', 90)
# SHIP: [-11577, -2008], WAYPOINT: [6, 20]
# ('W', 1)
# SHIP: [-11577, -2008], WAYPOINT: [5, 20]
# ('E', 2)
# SHIP: [-11577, -2008], WAYPOINT: [7, 20]
# ('R', 90)
# SHIP: [-11577, -2008], WAYPOINT: [20, -7]
# ('F', 50)
# SHIP: [-10577, -2358], WAYPOINT: [20, -7]
# ('S', 2)
# SHIP: [-10577, -2358], WAYPOINT: [20, -9]
# ('W', 5)
# SHIP: [-10577, -2358], WAYPOINT: [15, -9]
# ('F', 86)
# SHIP: [-9287, -3132], WAYPOINT: [15, -9]
# ('S', 1)
# SHIP: [-9287, -3132], WAYPOINT: [15, -10]
# ('L', 90)
# SHIP: [-9287, -3132], WAYPOINT: [10, 15]
# ('S', 3)
# SHIP: [-9287, -3132], WAYPOINT: [10, 12]
# ('F', 8)
# SHIP: [-9207, -3036], WAYPOINT: [10, 12]
# ('L', 90)
# SHIP: [-9207, -3036], WAYPOINT: [-12, 10]
# ('E', 2)
# SHIP: [-9207, -3036], WAYPOINT: [-10, 10]
# ('F', 36)
# SHIP: [-9567, -2676], WAYPOINT: [-10, 10]
# ('L', 180)
# SHIP: [-9567, -2676], WAYPOINT: [10, -10]
# ('E', 4)
# SHIP: [-9567, -2676], WAYPOINT: [14, -10]
# ('R', 180)
# SHIP: [-9567, -2676], WAYPOINT: [-14, 10]
# ('E', 3)
# SHIP: [-9567, -2676], WAYPOINT: [-11, 10]
# ('N', 3)
# SHIP: [-9567, -2676], WAYPOINT: [-11, 13]
# ('E', 1)
# SHIP: [-9567, -2676], WAYPOINT: [-10, 13]
# ('F', 94)
# SHIP: [-10507, -1454], WAYPOINT: [-10, 13]
# ('N', 3)
# SHIP: [-10507, -1454], WAYPOINT: [-10, 16]
# ('F', 64)
# SHIP: [-11147, -430], WAYPOINT: [-10, 16]
# ('L', 90)
# SHIP: [-11147, -430], WAYPOINT: [-16, -10]
# ('S', 1)
# SHIP: [-11147, -430], WAYPOINT: [-16, -11]
# ('S', 1)
# SHIP: [-11147, -430], WAYPOINT: [-16, -12]
# ('F', 33)
# SHIP: [-11675, -826], WAYPOINT: [-16, -12]
# ('E', 3)
# SHIP: [-11675, -826], WAYPOINT: [-13, -12]
# ('S', 1)
# SHIP: [-11675, -826], WAYPOINT: [-13, -13]
# ('L', 90)
# SHIP: [-11675, -826], WAYPOINT: [13, -13]
# ('N', 3)
# SHIP: [-11675, -826], WAYPOINT: [13, -10]
# ('W', 5)
# SHIP: [-11675, -826], WAYPOINT: [8, -10]
# ('N', 4)
# SHIP: [-11675, -826], WAYPOINT: [8, -6]
# ('L', 90)
# SHIP: [-11675, -826], WAYPOINT: [6, 8]
# ('F', 53)
# SHIP: [-11357, -402], WAYPOINT: [6, 8]
# ('W', 1)
# SHIP: [-11357, -402], WAYPOINT: [5, 8]
# ('N', 5)
# SHIP: [-11357, -402], WAYPOINT: [5, 13]
# ('F', 67)
# SHIP: [-11022, 469], WAYPOINT: [5, 13]
# ('E', 2)
# SHIP: [-11022, 469], WAYPOINT: [7, 13]
# ('F', 43)
# SHIP: [-10721, 1028], WAYPOINT: [7, 13]
# ('N', 5)
# SHIP: [-10721, 1028], WAYPOINT: [7, 18]
# ('W', 3)
# SHIP: [-10721, 1028], WAYPOINT: [4, 18]
# ('W', 3)
# SHIP: [-10721, 1028], WAYPOINT: [1, 18]
# ('L', 90)
# SHIP: [-10721, 1028], WAYPOINT: [-18, 1]
# ('L', 90)
# SHIP: [-10721, 1028], WAYPOINT: [-1, -18]
# ('E', 1)
# SHIP: [-10721, 1028], WAYPOINT: [0, -18]
# ('S', 4)
# SHIP: [-10721, 1028], WAYPOINT: [0, -22]
# ('W', 3)
# SHIP: [-10721, 1028], WAYPOINT: [-3, -22]
# ('R', 180)
# SHIP: [-10721, 1028], WAYPOINT: [3, 22]
# ('S', 1)
# SHIP: [-10721, 1028], WAYPOINT: [3, 21]
# ('F', 79)
# SHIP: [-10484, 2687], WAYPOINT: [3, 21]
# ('S', 2)
# SHIP: [-10484, 2687], WAYPOINT: [3, 19]
# ('W', 2)
# SHIP: [-10484, 2687], WAYPOINT: [1, 19]
# ('F', 23)
# SHIP: [-10461, 3124], WAYPOINT: [1, 19]
# ('L', 90)
# SHIP: [-10461, 3124], WAYPOINT: [-19, 1]
# ('W', 3)
# SHIP: [-10461, 3124], WAYPOINT: [-22, 1]
# ('F', 65)
# SHIP: [-11891, 3189], WAYPOINT: [-22, 1]
# ('E', 1)
# SHIP: [-11891, 3189], WAYPOINT: [-21, 1]
# ('R', 180)
# SHIP: [-11891, 3189], WAYPOINT: [21, -1]
# ('E', 4)
# SHIP: [-11891, 3189], WAYPOINT: [25, -1]
# ('N', 3)
# SHIP: [-11891, 3189], WAYPOINT: [25, 2]
# ('L', 180)
# SHIP: [-11891, 3189], WAYPOINT: [-25, -2]
# ('S', 4)
# SHIP: [-11891, 3189], WAYPOINT: [-25, -6]
# ('E', 3)
# SHIP: [-11891, 3189], WAYPOINT: [-22, -6]
# ('E', 5)
# SHIP: [-11891, 3189], WAYPOINT: [-17, -6]
# ('L', 90)
# SHIP: [-11891, 3189], WAYPOINT: [6, -17]
# ('F', 92)
# SHIP: [-11339, 1625], WAYPOINT: [6, -17]
# ('W', 4)
# SHIP: [-11339, 1625], WAYPOINT: [2, -17]
# ('F', 57)
# SHIP: [-11225, 656], WAYPOINT: [2, -17]
# ('S', 3)
# SHIP: [-11225, 656], WAYPOINT: [2, -20]
# ('L', 90)
# SHIP: [-11225, 656], WAYPOINT: [20, 2]
# ('S', 2)
# SHIP: [-11225, 656], WAYPOINT: [20, 0]
# ('L', 90)
# SHIP: [-11225, 656], WAYPOINT: [0, 20]
# ('S', 2)
# SHIP: [-11225, 656], WAYPOINT: [0, 18]
# ('F', 50)
# SHIP: [-11225, 1556], WAYPOINT: [0, 18]
# ('E', 3)
# SHIP: [-11225, 1556], WAYPOINT: [3, 18]
# ('L', 90)
# SHIP: [-11225, 1556], WAYPOINT: [-18, 3]
# ('S', 3)
# SHIP: [-11225, 1556], WAYPOINT: [-18, 0]
# ('R', 180)
# SHIP: [-11225, 1556], WAYPOINT: [18, 0]
# ('E', 4)
# SHIP: [-11225, 1556], WAYPOINT: [22, 0]
# ('F', 14)
# SHIP: [-10917, 1556], WAYPOINT: [22, 0]
# ('E', 5)
# SHIP: [-10917, 1556], WAYPOINT: [27, 0]
# ('S', 5)
# SHIP: [-10917, 1556], WAYPOINT: [27, -5]
# ('E', 3)
# SHIP: [-10917, 1556], WAYPOINT: [30, -5]
# ('N', 2)
# SHIP: [-10917, 1556], WAYPOINT: [30, -3]
# ('L', 180)
# SHIP: [-10917, 1556], WAYPOINT: [-30, 3]
# ('W', 4)
# SHIP: [-10917, 1556], WAYPOINT: [-34, 3]
# ('S', 5)
# SHIP: [-10917, 1556], WAYPOINT: [-34, -2]
# ('S', 1)
# SHIP: [-10917, 1556], WAYPOINT: [-34, -3]
# ('L', 90)
# SHIP: [-10917, 1556], WAYPOINT: [3, -34]
# ('F', 1)
# SHIP: [-10914, 1522], WAYPOINT: [3, -34]
# ('S', 4)
# SHIP: [-10914, 1522], WAYPOINT: [3, -38]
# ('F', 4)
# SHIP: [-10902, 1370], WAYPOINT: [3, -38]
# ('R', 90)
# SHIP: [-10902, 1370], WAYPOINT: [-38, -3]
# ('S', 5)
# SHIP: [-10902, 1370], WAYPOINT: [-38, -8]
# ('F', 15)
# SHIP: [-11472, 1250], WAYPOINT: [-38, -8]
# ('N', 4)
# SHIP: [-11472, 1250], WAYPOINT: [-38, -4]
# ('L', 90)
# SHIP: [-11472, 1250], WAYPOINT: [4, -38]
# ('W', 3)
# SHIP: [-11472, 1250], WAYPOINT: [1, -38]
# ('L', 90)
# SHIP: [-11472, 1250], WAYPOINT: [38, 1]
# ('S', 5)
# SHIP: [-11472, 1250], WAYPOINT: [38, -4]
# ('L', 270)
# SHIP: [-11472, 1250], WAYPOINT: [-4, -38]
# ('W', 1)
# SHIP: [-11472, 1250], WAYPOINT: [-5, -38]
# ('R', 90)
# SHIP: [-11472, 1250], WAYPOINT: [-38, 5]
# ('S', 3)
# SHIP: [-11472, 1250], WAYPOINT: [-38, 2]
# ('L', 90)
# SHIP: [-11472, 1250], WAYPOINT: [-2, -38]
# ('W', 4)
# SHIP: [-11472, 1250], WAYPOINT: [-6, -38]
# ('F', 16)
# SHIP: [-11568, 642], WAYPOINT: [-6, -38]
# ('R', 90)
# SHIP: [-11568, 642], WAYPOINT: [-38, 6]
# ('S', 1)
# SHIP: [-11568, 642], WAYPOINT: [-38, 5]
# ('F', 61)
# SHIP: [-13886, 947], WAYPOINT: [-38, 5]
# ('L', 90)
# SHIP: [-13886, 947], WAYPOINT: [-5, -38]
# ('N', 5)
# SHIP: [-13886, 947], WAYPOINT: [-5, -33]
# ('R', 90)
# SHIP: [-13886, 947], WAYPOINT: [-33, 5]
# ('F', 21)
# SHIP: [-14579, 1052], WAYPOINT: [-33, 5]
# ('R', 90)
# SHIP: [-14579, 1052], WAYPOINT: [5, 33]
# ('N', 4)
# SHIP: [-14579, 1052], WAYPOINT: [5, 37]
# ('W', 1)
# SHIP: [-14579, 1052], WAYPOINT: [4, 37]
# ('F', 36)
# SHIP: [-14435, 2384], WAYPOINT: [4, 37]
# ('S', 1)
# SHIP: [-14435, 2384], WAYPOINT: [4, 36]
# ('L', 90)
# SHIP: [-14435, 2384], WAYPOINT: [-36, 4]
# ('W', 4)
# SHIP: [-14435, 2384], WAYPOINT: [-40, 4]
# ('R', 90)
# SHIP: [-14435, 2384], WAYPOINT: [4, 40]
# ('E', 3)
# SHIP: [-14435, 2384], WAYPOINT: [7, 40]
# ('N', 1)
# SHIP: [-14435, 2384], WAYPOINT: [7, 41]
# ('F', 68)
# SHIP: [-13959, 5172], WAYPOINT: [7, 41]
# ('N', 4)
# SHIP: [-13959, 5172], WAYPOINT: [7, 45]
# ('E', 4)
# SHIP: [-13959, 5172], WAYPOINT: [11, 45]
# ('R', 90)
# SHIP: [-13959, 5172], WAYPOINT: [45, -11]
# ('E', 5)
# SHIP: [-13959, 5172], WAYPOINT: [50, -11]
# ('S', 1)
# SHIP: [-13959, 5172], WAYPOINT: [50, -12]
# ('R', 90)
# SHIP: [-13959, 5172], WAYPOINT: [-12, -50]
# ('F', 2)
# SHIP: [-13983, 5072], WAYPOINT: [-12, -50]
# ('R', 90)
# SHIP: [-13983, 5072], WAYPOINT: [-50, 12]
# ('E', 3)
# SHIP: [-13983, 5072], WAYPOINT: [-47, 12]
# ('W', 2)
# SHIP: [-13983, 5072], WAYPOINT: [-49, 12]
# ('R', 180)
# SHIP: [-13983, 5072], WAYPOINT: [49, -12]
# ('F', 13)
# SHIP: [-13346, 4916], WAYPOINT: [49, -12]
# ('R', 90)
# SHIP: [-13346, 4916], WAYPOINT: [-12, -49]
# ('S', 5)
# SHIP: [-13346, 4916], WAYPOINT: [-12, -54]
# ('F', 99)
# SHIP: [-14534, -430], WAYPOINT: [-12, -54]
# ('E', 5)
# SHIP: [-14534, -430], WAYPOINT: [-7, -54]
# ('R', 90)
# SHIP: [-14534, -430], WAYPOINT: [-54, 7]
# ('F', 8)
# SHIP: [-14966, -374], WAYPOINT: [-54, 7]
# ('S', 5)
# SHIP: [-14966, -374], WAYPOINT: [-54, 2]
# ('F', 54)
# SHIP: [-17882, -266], WAYPOINT: [-54, 2]
# ('L', 90)
# SHIP: [-17882, -266], WAYPOINT: [-2, -54]
# ('S', 4)
# SHIP: [-17882, -266], WAYPOINT: [-2, -58]
# ('R', 180)
# SHIP: [-17882, -266], WAYPOINT: [2, 58]
# ('W', 2)
# SHIP: [-17882, -266], WAYPOINT: [0, 58]
# ('S', 1)
# SHIP: [-17882, -266], WAYPOINT: [0, 57]
# ('F', 32)
# SHIP: [-17882, 1558], WAYPOINT: [0, 57]
# ('W', 3)
# SHIP: [-17882, 1558], WAYPOINT: [-3, 57]
# ('N', 2)
# SHIP: [-17882, 1558], WAYPOINT: [-3, 59]
# ('W', 3)
# SHIP: [-17882, 1558], WAYPOINT: [-6, 59]
# ('N', 3)
# SHIP: [-17882, 1558], WAYPOINT: [-6, 62]
# ('E', 2)
# SHIP: [-17882, 1558], WAYPOINT: [-4, 62]
# ('N', 2)
# SHIP: [-17882, 1558], WAYPOINT: [-4, 64]
# ('R', 180)
# SHIP: [-17882, 1558], WAYPOINT: [4, -64]
# ('S', 5)
# SHIP: [-17882, 1558], WAYPOINT: [4, -69]
# ('E', 1)
# SHIP: [-17882, 1558], WAYPOINT: [5, -69]
# ('R', 90)
# SHIP: [-17882, 1558], WAYPOINT: [-69, -5]
# ('F', 73)
# SHIP: [-22919, 1193], WAYPOINT: [-69, -5]
# ('L', 90)
# SHIP: [-22919, 1193], WAYPOINT: [5, -69]
# ('W', 4)
# SHIP: [-22919, 1193], WAYPOINT: [1, -69]
# ('R', 90)
# SHIP: [-22919, 1193], WAYPOINT: [-69, -1]
# ('S', 4)
# SHIP: [-22919, 1193], WAYPOINT: [-69, -5]
# ('F', 29)
# SHIP: [-24920, 1048], WAYPOINT: [-69, -5]
# ('F', 60)
# SHIP: [-29060, 748], WAYPOINT: [-69, -5]
# ('L', 90)
# SHIP: [-29060, 748], WAYPOINT: [5, -69]
# ('N', 5)
# SHIP: [-29060, 748], WAYPOINT: [5, -64]
# ('E', 3)
# SHIP: [-29060, 748], WAYPOINT: [8, -64]
# ('N', 5)
# SHIP: [-29060, 748], WAYPOINT: [8, -59]
# ('E', 1)
# SHIP: [-29060, 748], WAYPOINT: [9, -59]
# ('F', 94)
# SHIP: [-28214, -4798], WAYPOINT: [9, -59]
# ('N', 1)
# SHIP: [-28214, -4798], WAYPOINT: [9, -58]
# ('E', 5)
# SHIP: [-28214, -4798], WAYPOINT: [14, -58]
# ('R', 180)
# SHIP: [-28214, -4798], WAYPOINT: [-14, 58]
# ('N', 3)
# SHIP: [-28214, -4798], WAYPOINT: [-14, 61]
# ('E', 2)
# SHIP: [-28214, -4798], WAYPOINT: [-12, 61]
# ('R', 90)
# SHIP: [-28214, -4798], WAYPOINT: [61, 12]
# ('W', 3)
# SHIP: [-28214, -4798], WAYPOINT: [58, 12]
# ('L', 180)
# SHIP: [-28214, -4798], WAYPOINT: [-58, -12]
# ('F', 55)
# SHIP: [-31404, -5458], WAYPOINT: [-58, -12]
# ('N', 2)
# SHIP: [-31404, -5458], WAYPOINT: [-58, -10]
# ('W', 2)
# SHIP: [-31404, -5458], WAYPOINT: [-60, -10]
# ('R', 270)
# SHIP: [-31404, -5458], WAYPOINT: [10, -60]
# ('F', 64)
# SHIP: [-30764, -9298], WAYPOINT: [10, -60]
# ('E', 5)
# SHIP: [-30764, -9298], WAYPOINT: [15, -60]
# ('W', 1)
# SHIP: [-30764, -9298], WAYPOINT: [14, -60]
# ('N', 4)
# SHIP: [-30764, -9298], WAYPOINT: [14, -56]
# ('E', 4)
# SHIP: [-30764, -9298], WAYPOINT: [18, -56]
# ('N', 3)
# SHIP: [-30764, -9298], WAYPOINT: [18, -53]
# ('E', 1)
# SHIP: [-30764, -9298], WAYPOINT: [19, -53]
# ('R', 90)
# SHIP: [-30764, -9298], WAYPOINT: [-53, -19]
# ('E', 1)
# SHIP: [-30764, -9298], WAYPOINT: [-52, -19]
# ('S', 4)
# SHIP: [-30764, -9298], WAYPOINT: [-52, -23]
# ('L', 270)
# SHIP: [-30764, -9298], WAYPOINT: [-23, 52]
# ('W', 4)
# SHIP: [-30764, -9298], WAYPOINT: [-27, 52]
# ('S', 4)
# SHIP: [-30764, -9298], WAYPOINT: [-27, 48]
# ('L', 180)
# SHIP: [-30764, -9298], WAYPOINT: [27, -48]
# ('F', 33)
# SHIP: [-29873, -10882], WAYPOINT: [27, -48]
# ('R', 90)
# SHIP: [-29873, -10882], WAYPOINT: [-48, -27]
# ('E', 5)
# SHIP: [-29873, -10882], WAYPOINT: [-43, -27]
# ('S', 2)
# SHIP: [-29873, -10882], WAYPOINT: [-43, -29]
# ('W', 3)
# SHIP: [-29873, -10882], WAYPOINT: [-46, -29]
# ('W', 5)
# SHIP: [-29873, -10882], WAYPOINT: [-51, -29]
# ('N', 3)
# SHIP: [-29873, -10882], WAYPOINT: [-51, -26]
# ('W', 2)
# SHIP: [-29873, -10882], WAYPOINT: [-53, -26]
# ('F', 20)
# SHIP: [-30933, -11402], WAYPOINT: [-53, -26]
# ('W', 5)
# SHIP: [-30933, -11402], WAYPOINT: [-58, -26]
# ('S', 3)
# SHIP: [-30933, -11402], WAYPOINT: [-58, -29]
# ('W', 3)
# SHIP: [-30933, -11402], WAYPOINT: [-61, -29]
# ('R', 180)
# SHIP: [-30933, -11402], WAYPOINT: [61, 29]
# ('F', 99)
# SHIP: [-24894, -8531], WAYPOINT: [61, 29]
# ('E', 1)
# SHIP: [-24894, -8531], WAYPOINT: [62, 29]
# ('F', 4)
# SHIP: [-24646, -8415], WAYPOINT: [62, 29]
# ('E', 5)
# SHIP: [-24646, -8415], WAYPOINT: [67, 29]
# ('F', 34)
# SHIP: [-22368, -7429], WAYPOINT: [67, 29]
# ('F', 1)
# SHIP: [-22301, -7400], WAYPOINT: [67, 29]
# ('F', 43)
# SHIP: [-19420, -6153], WAYPOINT: [67, 29]
# ('S', 4)
# SHIP: [-19420, -6153], WAYPOINT: [67, 25]
# ('E', 5)
# SHIP: [-19420, -6153], WAYPOINT: [72, 25]
# ('R', 90)
# SHIP: [-19420, -6153], WAYPOINT: [25, -72]
# ('N', 5)
# SHIP: [-19420, -6153], WAYPOINT: [25, -67]
# ('F', 95)
# SHIP: [-17045, -12518], WAYPOINT: [25, -67]
# ('W', 4)
# SHIP: [-17045, -12518], WAYPOINT: [21, -67]
# ('F', 10)
# SHIP: [-16835, -13188], WAYPOINT: [21, -67]
# ('N', 1)
# SHIP: [-16835, -13188], WAYPOINT: [21, -66]
# ('L', 90)
# SHIP: [-16835, -13188], WAYPOINT: [66, 21]
# ('S', 4)
# SHIP: [-16835, -13188], WAYPOINT: [66, 17]
# ('W', 2)
# SHIP: [-16835, -13188], WAYPOINT: [64, 17]
# ('L', 90)
# SHIP: [-16835, -13188], WAYPOINT: [-17, 64]
# ('F', 41)
# SHIP: [-17532, -10564], WAYPOINT: [-17, 64]
# ('L', 270)
# SHIP: [-17532, -10564], WAYPOINT: [64, 17]
# ('F', 89)
# SHIP: [-11836, -9051], WAYPOINT: [64, 17]
# ('L', 90)
# SHIP: [-11836, -9051], WAYPOINT: [-17, 64]
# ('F', 34)
# SHIP: [-12414, -6875], WAYPOINT: [-17, 64]
# ('N', 5)
# SHIP: [-12414, -6875], WAYPOINT: [-17, 69]
# ('F', 2)
# SHIP: [-12448, -6737], WAYPOINT: [-17, 69]
# ('W', 3)
# SHIP: [-12448, -6737], WAYPOINT: [-20, 69]
# ('F', 27)
# SHIP: [-12988, -4874], WAYPOINT: [-20, 69]
# ('S', 1)
# SHIP: [-12988, -4874], WAYPOINT: [-20, 68]
# ('R', 270)
# SHIP: [-12988, -4874], WAYPOINT: [-68, -20]
# ('W', 3)
# SHIP: [-12988, -4874], WAYPOINT: [-71, -20]
# ('N', 2)
# SHIP: [-12988, -4874], WAYPOINT: [-71, -18]
# ('R', 90)
# SHIP: [-12988, -4874], WAYPOINT: [-18, 71]
# ('F', 13)
# SHIP: [-13222, -3951], WAYPOINT: [-18, 71]
# ('N', 1)
# SHIP: [-13222, -3951], WAYPOINT: [-18, 72]
# ('F', 78)
# SHIP: [-14626, 1665], WAYPOINT: [-18, 72]
# ('W', 4)
# SHIP: [-14626, 1665], WAYPOINT: [-22, 72]
# ('R', 90)
# SHIP: [-14626, 1665], WAYPOINT: [72, 22]
# ('S', 5)
# SHIP: [-14626, 1665], WAYPOINT: [72, 17]
# ('F', 27)
# SHIP: [-12682, 2124], WAYPOINT: [72, 17]
# ('N', 5)
# SHIP: [-12682, 2124], WAYPOINT: [72, 22]
# ('E', 4)
# SHIP: [-12682, 2124], WAYPOINT: [76, 22]
# ('F', 61)
# SHIP: [-8046, 3466], WAYPOINT: [76, 22]
# ('L', 180)
# SHIP: [-8046, 3466], WAYPOINT: [-76, -22]
# ('N', 2)
# SHIP: [-8046, 3466], WAYPOINT: [-76, -20]
# ('R', 90)
# SHIP: [-8046, 3466], WAYPOINT: [-20, 76]
# ('W', 5)
# SHIP: [-8046, 3466], WAYPOINT: [-25, 76]
# ('S', 4)
# SHIP: [-8046, 3466], WAYPOINT: [-25, 72]
# ('S', 4)
# SHIP: [-8046, 3466], WAYPOINT: [-25, 68]
# ('E', 1)
# SHIP: [-8046, 3466], WAYPOINT: [-24, 68]
# ('F', 8)
# SHIP: [-8238, 4010], WAYPOINT: [-24, 68]
# ('R', 90)
# SHIP: [-8238, 4010], WAYPOINT: [68, 24]
# ('E', 2)
# SHIP: [-8238, 4010], WAYPOINT: [70, 24]
# ('R', 90)
# SHIP: [-8238, 4010], WAYPOINT: [24, -70]
# ('E', 5)
# SHIP: [-8238, 4010], WAYPOINT: [29, -70]
# ('F', 1)
# SHIP: [-8209, 3940], WAYPOINT: [29, -70]
# ('E', 1)
# SHIP: [-8209, 3940], WAYPOINT: [30, -70]
# ('L', 90)
# SHIP: [-8209, 3940], WAYPOINT: [70, 30]
# ('F', 32)
# SHIP: [-5969, 4900], WAYPOINT: [70, 30]
# ('W', 3)
# SHIP: [-5969, 4900], WAYPOINT: [67, 30]
# ('S', 1)
# SHIP: [-5969, 4900], WAYPOINT: [67, 29]
# ('S', 3)
# SHIP: [-5969, 4900], WAYPOINT: [67, 26]
# ('R', 90)
# SHIP: [-5969, 4900], WAYPOINT: [26, -67]
# ('E', 5)
# SHIP: [-5969, 4900], WAYPOINT: [31, -67]
# ('F', 84)
# SHIP: [-3365, -728], WAYPOINT: [31, -67]
# ('N', 3)
# SHIP: [-3365, -728], WAYPOINT: [31, -64]
# ('F', 17)
# SHIP: [-2838, -1816], WAYPOINT: [31, -64]
# ('R', 90)
# SHIP: [-2838, -1816], WAYPOINT: [-64, -31]
# ('S', 2)
# SHIP: [-2838, -1816], WAYPOINT: [-64, -33]
# ('F', 80)
# SHIP: [-7958, -4456], WAYPOINT: [-64, -33]
# ('L', 90)
# SHIP: [-7958, -4456], WAYPOINT: [33, -64]
# ('F', 84)
# SHIP: [-5186, -9832], WAYPOINT: [33, -64]
# ('S', 1)
# SHIP: [-5186, -9832], WAYPOINT: [33, -65]
# ('F', 63)
# SHIP: [-3107, -13927], WAYPOINT: [33, -65]
# ('R', 90)
# SHIP: [-3107, -13927], WAYPOINT: [-65, -33]
# ('N', 1)
# SHIP: [-3107, -13927], WAYPOINT: [-65, -32]
# ('R', 90)
# SHIP: [-3107, -13927], WAYPOINT: [-32, 65]
# ('N', 3)
# SHIP: [-3107, -13927], WAYPOINT: [-32, 68]
# ('F', 88)
# SHIP: [-5923, -7943], WAYPOINT: [-32, 68]
# ('F', 16)
# SHIP: [-6435, -6855], WAYPOINT: [-32, 68]
# ('N', 3)
# SHIP: [-6435, -6855], WAYPOINT: [-32, 71]
# ('W', 1)
# SHIP: [-6435, -6855], WAYPOINT: [-33, 71]
# ('N', 5)
# SHIP: [-6435, -6855], WAYPOINT: [-33, 76]
# ('L', 180)
# SHIP: [-6435, -6855], WAYPOINT: [33, -76]
# ('S', 5)
# SHIP: [-6435, -6855], WAYPOINT: [33, -81]
# ('F', 66)
# SHIP: [-4257, -12201], WAYPOINT: [33, -81]
# ('R', 90)
# SHIP: [-4257, -12201], WAYPOINT: [-81, -33]
# ('W', 1)
# SHIP: [-4257, -12201], WAYPOINT: [-82, -33]
# ('F', 85)
# SHIP: [-11227, -15006], WAYPOINT: [-82, -33]
# ('S', 1)
# SHIP: [-11227, -15006], WAYPOINT: [-82, -34]
# ('F', 69)
# SHIP: [-16885, -17352], WAYPOINT: [-82, -34]
# ('R', 180)
# SHIP: [-16885, -17352], WAYPOINT: [82, 34]
# ('S', 3)
# SHIP: [-16885, -17352], WAYPOINT: [82, 31]
# ('F', 67)
# SHIP: [-11391, -15275], WAYPOINT: [82, 31]
# ('F', 69)
# SHIP: [-5733, -13136], WAYPOINT: [82, 31]
# ('W', 2)
# SHIP: [-5733, -13136], WAYPOINT: [80, 31]
# ('F', 72)
# SHIP: [27, -10904], WAYPOINT: [80, 31]
# ('R', 180)
# SHIP: [27, -10904], WAYPOINT: [-80, -31]
# ('W', 5)
# SHIP: [27, -10904], WAYPOINT: [-85, -31]
# ('F', 13)
# SHIP: [-1078, -11307], WAYPOINT: [-85, -31]

# %%
s.manhattan_distance
# Out:
# 12385
